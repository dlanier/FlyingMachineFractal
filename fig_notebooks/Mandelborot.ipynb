# %%
from IPython.display import Latex
Latex(r"""\begin{eqnarray} \large 
Z_{n+1} = Z_{n}^2 - p
\end{eqnarray}""")
# Out:
# \begin{eqnarray} \large
# Z_{n+1} = Z_{n}^2 - p
# \end{eqnarray}

# %% [markdown]
# # History of a numerical mystery.
# * differential equation dynamics:
#     * numerical iteration vs solution
#     * sensitivity to initial conditions

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import sys   
import numpy as np
import time

from IPython.display import display

sys.path.insert(1, '../src');
import z_plane as zp
import graphic_utility as gu;
import itergataters as ig
import numcolorpy as ncp

separable = 0.7958 + 0.1893j 
iconic = 0.7757 + 0.1234j
spirals = 0.7513 + 0.2551j
ropey = 0.81 + 0.2025j

# %%
def ReneM(Z, p, Z0=None, ET=None):
    """ Z = bugga_bear(Z, p) 
    Args:
        Z:    a real or complex number
        p:    a real of complex number
    Returns:
        Z:    the result (complex)
    """
    return Z**2 - Z0

# %%
#                                        -- define parameters iterate the above equation  --  "separable" parameter p
par_set = {'n_rows': 570, 'n_cols': 923}
par_set['center_point'] = 1.0 + 0.0*1j
par_set['theta'] = 0
par_set['zoom'] = 3/4

par_set['it_max'] = 4096
par_set['max_d'] = 10 / par_set['zoom']
par_set['dir_path'] = os.getcwd()

list_tuple = [(ReneM, (0.0 + 0.0j))]

t0 = time.time()
ET, Z, Z0 = ig.get_primitives(list_tuple, par_set)
print(time.time() - t0, '\t total time')

#                  escape time graphical norm
t0 = time.time()
Zd, Zr, ETn = ncp.etg_norm(Z0, Z, ET)
print('converstion time =\t', time.time() - t0)

H = ncp.range_norm(Zr - Zd, lo=0.5, hi=0.85)
S = ncp.range_norm(1 - ETn, lo=0.0, hi=0.9)
V = ncp.range_norm(ETn, lo=0.0, hi=1.0)
t0 = time.time()
Ihsv = ncp.rgb_2_hsv_mat(H, S, V)
print('coloring time:\t',time.time() - t0)
display(Ihsv)
# Out:
# 467.59887194633484 	 total time
# converstion time =	 1.136916160583496
# coloring time:	 5.922814846038818
# <PIL.Image.Image image mode=RGB size=923x570 at 0x107A01F98>

# %%
t0 = time.time()
ETd = ncp.mat_to_gray(ETn)
print('coloring time =\t',time.time() - t0)
display(ETd)
# Out:
# coloring time =	 2.8482251167297363
# <PIL.Image.Image image mode=RGB size=923x570 at 0x107EE2A20>

# %%
H = ncp.range_norm(Zd - Zr, lo=0.0, hi=1.0)
S = ncp.range_norm(ETn, lo=0.0, hi=1.0)
V = ncp.range_norm(1 - ETn, lo=0.9, hi=1.0)
t0 = time.time()
Ihsv = ncp.rgb_2_hsv_mat(H, S, V)
print('coloring time:\t',time.time() - t0)
display(Ihsv)
# Out:
# coloring time:	 5.838513135910034
# <PIL.Image.Image image mode=RGB size=923x570 at 0x107A01AC8>

# %%
H = ncp.range_norm(Zr * Zd, lo=0.6667, hi=1.0)
S = ncp.range_norm(ETn, lo=0.08, hi=1.0)
V = ncp.range_norm(ETn, lo=0.85, hi=1.0)
t0 = time.time()
Ihsv = ncp.rgb_2_hsv_mat(H, S, V)
print('coloring time:\t',time.time() - t0)
display(Ihsv)
# Out:
# coloring time:	 6.058138132095337
# <PIL.Image.Image image mode=RGB size=923x570 at 0x107A01A90>

# %%
H = ncp.range_norm(Zr - Zd, lo=0.5, hi=0.85)
S = ncp.range_norm(1 - ETn, lo=0.0, hi=0.9)
V = ncp.range_norm(ETn, lo=0.0, hi=1.0)
t0 = time.time()
Ihsv = ncp.rgb_2_hsv_mat(H, S, V)
print('coloring time:\t',time.time() - t0)
display(Ihsv)
# Out:
# coloring time:	 5.9035890102386475
# <PIL.Image.Image image mode=RGB size=923x570 at 0x106DD41D0>

# %%
H = ncp.range_norm(Zr - Zd, lo=0.5, hi=0.85)
S = ncp.range_norm(1 - ETn, lo=0.0, hi=0.9)
V = ncp.range_norm(ETn, lo=0.0, hi=1.0)
t0 = time.time()
Ihsv = ncp.rgb_2_hsv_mat(H, S, V)
print('coloring time:\t',time.time() - t0)
display(Ihsv)
# Out:
# coloring time:	 5.916375160217285
# <PIL.Image.Image image mode=RGB size=923x570 at 0x107A01908>

# %%
H = ncp.range_norm(Zd - Zr, lo=0.0, hi=1.0)
S = ncp.range_norm(ETn, lo=0.0, hi=1.0)
V = ncp.range_norm(1 - ETn, lo=0.9, hi=1.0)
t0 = time.time()
Ihsv = ncp.rgb_2_hsv_mat(H, S, V)
print('coloring time:\t',time.time() - t0)
display(Ihsv)
# Out:
# coloring time:	 5.9556050300598145
# <PIL.Image.Image image mode=RGB size=923x570 at 0x106DD41D0>

# %%
H = ncp.range_norm(Zr * Zd, lo=0.6667, hi=1.0)
S = ncp.range_norm(ETn, lo=0.08, hi=1.0)
V = ncp.range_norm(ETn, lo=0.85, hi=1.0)
t0 = time.time()
Ihsv = ncp.rgb_2_hsv_mat(H, S, V)
print('coloring time:\t',time.time() - t0)
display(Ihsv)
# Out:
# coloring time:	 6.036295175552368
# <PIL.Image.Image image mode=RGB size=923x570 at 0x106D4FFD0>

# %%
np.round(323 * (np.sqrt(5)-1)/2)
# Out:
# 200.0

# %%
#                                        smaller -> view individual escape time sets -- "iconic" 
par_set = {'n_rows': 200, 'n_cols': 323}
par_set['center_point'] = 0.0 + 0.0*1j
par_set['theta'] = np.pi / 4
par_set['zoom'] = 3/4

par_set['it_max'] = 128
par_set['max_d'] = 10 / par_set['zoom']
par_set['dir_path'] = os.getcwd()

list_tuple = [(ReneM, (0.0 + 0.0j))]

t0 = time.time()
ET_sm, Z_sm, Z0_sm = ig.get_primitives(list_tuple, par_set)
print(time.time() - t0, '\t total time')

#                  escape time graphical norm
t0 = time.time()
Zd_sm, Zr_sm, ETn_sm = ncp.etg_norm(Z0_sm, Z_sm, ET_sm)
print('converstion time =\t', time.time() - t0)
# Out:
# 2.6454670429229736 	 total time
# converstion time =	 0.136152982711792

# %%
#                  Escape Time: darker escaped sooner
t0 = time.time()
ETd = ncp.mat_to_gray(ETn_sm)
print('coloring time =\t',time.time() - t0)
display(ETd)
# Out:
# coloring time =	 0.36966705322265625
# <PIL.Image.Image image mode=RGB size=323x200 at 0x1078E7EF0>

# %%
#                  Distance at Escape Time: lighter traveled further
t0 = time.time()
D = ncp.mat_to_gray(Zd_sm, max_v=255, min_v=64)
print('coloring time =\t',time.time() - t0)
display(D)
# Out:
# coloring time =	 0.3611299991607666
# <PIL.Image.Image image mode=RGB size=323x200 at 0x106E50F28>

# %%
#                  Rotation at Escape Time: lighter rotated more
t0 = time.time()
R = ncp.mat_to_gray(Zr_sm, max_v=255, min_v=64)
print('coloring time =\t',time.time() - t0)
display(R)
# Out:
# coloring time =	 0.35571908950805664
# <PIL.Image.Image image mode=RGB size=323x200 at 0x1078E79E8>

# %%
#                                        view smaller - individual escape time starting points
lo_ET = 2
hi_ET = lo_ET + 6
for t in range(lo_ET, hi_ET):
    print('ET =\t',t)
    I = np.ones(ET_sm.shape)
    I[ET_sm == t] = 0
    display(ncp.mat_to_gray(I))
I = np.ones(ET_sm.shape)
I[ET_sm > hi_ET] = 0
print('ET >\t',hi_ET)
display(ncp.mat_to_gray(I))
# Out:
# ET =	 2
# <PIL.Image.Image image mode=RGB size=323x200 at 0x107CF0748>
# ET =	 3
# <PIL.Image.Image image mode=RGB size=323x200 at 0x107CF0710>
# ET =	 4
# <PIL.Image.Image image mode=RGB size=323x200 at 0x107CF0710>
# ET =	 5
# <PIL.Image.Image image mode=RGB size=323x200 at 0x107CF0748>
# ET =	 6
# <PIL.Image.Image image mode=RGB size=323x200 at 0x107CF0710>
# ET =	 7
# <PIL.Image.Image image mode=RGB size=323x200 at 0x107CF0710>
# ET >	 8
# <PIL.Image.Image image mode=RGB size=323x200 at 0x107CF0710>

# %%
#                                        view smaller - individual escape time frequency
for k in range(0,int(ET_sm.max())):
    print(k, (ET_sm == k).sum())
print('\nHow many never escaped:\n>',(ET_sm > k).sum())
# Out:
# 0 0
# 1 0
# 2 15062
# 3 19389
# 4 8090
# 5 4205
# 6 2445
# 7 1484
# 8 1016
# 9 727
# 10 521
# 11 402
# 12 310
# 13 264
# 14 210
# 15 176
# 16 170
# 17 108
# 18 112
# 19 91
# 20 80
# 21 78
# 22 75
# 23 59
# 24 58
# 25 53
# 26 43
# 27 35
# 28 31
# 29 38
# 30 29
# 31 32
# 32 29
# 33 35
# 34 19
# 35 22
# 36 26
# 37 22
# 38 13
# 39 15
# 40 21
# 41 9
# 42 8
# 43 16
# 44 11
# 45 21
# 46 15
# 47 10
# 48 13
# 49 11
# 50 11
# 51 11
# 52 8
# 53 6
# 54 14
# 55 5
# 56 9
# 57 6
# 58 6
# 59 9
# 60 12
# 61 7
# 62 2
# 63 6
# 64 4
# 65 5
# 66 3
# 67 7
# 68 5
# 69 5
# 70 2
# 71 4
# 72 5
# 73 3
# 74 4
# 75 6
# 76 5
# 77 5
# 78 4
# 79 5
# 80 3
# 81 1
# 82 2
# 83 9
# 84 2
# 85 4
# 86 1
# 87 5
# 88 3
# 89 3
# 90 2
# 91 4
# 92 5
# 93 6
# 94 5
# 95 4
# 96 3
# 97 2
# 98 2
# 99 4
# 100 3
# 101 1
# 102 8
# 103 3
# 104 2
# 105 1
# 106 2
# 107 0
# 108 2
# 109 4
# 110 1
# 111 1
# 112 1
# 113 3
# 114 1
# 115 0
# 116 1
# 117 2
# 118 1
# 119 4
# 120 1
# 121 4
# 122 1
# 123 0
# 124 1
# 125 0
# 126 2
# 127 1
# 128 1
#
# How many never escaped:
# > 8585

# %%
#                           get the list of unescaped starting points and look for orbit points
Z_overs = Z0_sm[ET_sm == ET_sm.max()]

v1 = Z_overs[0]
d = '%0.2f'%(np.abs(v1))
theta = '%0.1f'%(180*np.arctan2(np.imag(v1), np.real(v1))/np.pi)
print('Unescaped Vector:\n\tV = ', d, theta, 'degrees\n')

print('%9d'%Z_overs.size, 'total unescaped points\n')
print('%9s'%('points'), 'near V', '      (plane units)')
for denom0 in range(1,12):
    neighbor_distance = np.abs(v1) * 1/denom0
    v1_list = Z_overs[np.abs(Z_overs-v1) < neighbor_distance]
    print('%9d'%len(v1_list), 'within V/%2d  (%0.3f)'%(denom0, neighbor_distance))
# Out:
# Unescaped Vector:
# 	V =  0.66 120.8 degrees
#
#      8585 total unescaped points
#
#    points near V       (plane units)
#      2302 within V/ 1  (0.656)
#       539 within V/ 2  (0.328)
#       212 within V/ 3  (0.219)
#       106 within V/ 4  (0.164)
#        61 within V/ 5  (0.131)
#        48 within V/ 6  (0.109)
#        39 within V/ 7  (0.094)
#        35 within V/ 8  (0.082)
#        29 within V/ 9  (0.073)
#        22 within V/10  (0.066)
#        19 within V/11  (0.060)
