# %% [markdown]
# # bug_bear_libby - discovery:
# ### figure of a bug? or bug of a figure?
#
#     Iteration of difference equation:
#     Z = 1/Z - Z^( n*Z^(c(n)^n )/k);
#     on the complex plane produces a bug like figure.

# %%
# %matplotlib inline
import matplotlib;              import matplotlib.pyplot as plt
import matplotlib.image as ip;  hmb = plt.imshow(ip.imread('BugaBear.tif'))

# %%
import os;                       import sys
sys.path.insert(1, '../src');    import z_plane as zp

# %%
# c = [-0.851612290000,-1.794358160000,-4.450415130000];  theta = pi/2;
# ETM = 256;                          ETB = 133;
# CP = -1.0 + i*0.0;                  ZM = 0.02;

# def bug_bear_libby(Z0, p, et_max, et_dist):
#     Z_grid = Z0.copy()
#     # p = [2.76544+0.997995j, 50.1518+7.53287j]
#     p0 = 3.0/2.0
#     p1 = p[0]
#     p2 = p[1]
#     ET = np.zeros(Z_grid.shape, dtype='int32')
#     for r in range(0, Z_grid.shape[0]):
#         for c in range(0, Z_grid.shape[1]):
#             z0 = Z_grid[r, c]
#             zN = z0
#             while (np.isfinite(zN)) & (abs(zN - z0) < et_dist) & (ET[r, c] < et_max):
#                 z = zN
#                 ET[r, c] += 1
#                 zN = z**(p0 * z**(1j * p1**(p0 * z**p2)))
# #                 Z = 1/Z - Z^( n*Z^(c(n)^n )/k);
#             Z_grid[r, c] = z
            
#     return Z_grid, ET
