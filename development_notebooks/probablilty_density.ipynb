# %% [markdown]
# ## probablility density functions
# \begin{align}
# \mbox{Gaussian} \\
# \ g(y, \mu, \sigma) = \frac{1}{\sigma \sqrt{2 \pi}}  \exp{\frac{-(y - \mu)^2}{2 \sigma^2}} \\
# \end{align}
# ## adaptable parameters
# \begin{align}
# \Delta \mu = \alpha_{\mu} (r - b{\mu}) \frac{y - \mu}{\sigma^2} \\
# \\
# \Delta \sigma = \alpha_{\sigma} (r - b{\sigma}) \frac{(y - \mu)^2 - \sigma^2}{\sigma^3} \\
# \end{align}

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

def g(y,u,s):
    c = 1 / (np.sqrt(2*np.pi) * s)
    return c * np.exp((-(y-u)**2)/(2*s**2))

# %%
n_points = 1000
u = 6
s = 1
x = np.linspace(3, 9, n_points)
y = g(x,u,s)
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s - 0.9
s_hi = u + s
s_lo = u - s
print('number >= %0.2f'%cutoff, sum(np.random.normal(u,s, n_points) <= s_hi))
print('number >= %0.2f'%cutoff, sum(np.random.normal(u,s, n_points) <= s_lo))
# Out:
# number >= 7.00 805
# number >= 7.00 163
